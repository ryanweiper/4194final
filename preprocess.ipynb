# %%
# Goal: figure out what topics received the most citations in a given year
import pandas as pd
import numpy as np

# Open the data
data_str = open('C:\\Users\\Ryan\\Documents\\Ohio State\\8th Semester\\ECE 4194.02\\4194final\\acm1st10000.txt').read()
# data_str = open('C:\\Users\\Ryan\\Documents\\Ohio State\\8th Semester\\ECE 4194.02\\acm.txt', errors='ignore').read()
data_list = data_str.splitlines()

for i in range(10):
    print(data_list[i])

# Create the dataframe
    # title: (string -- should be bag of words vector)
    # authors: (list)
    # year: publishing year (int)
    # venue: journal the paper was published in (string)
    # ind: numeric label/index of this paper (int)
    # ref_indces: identification index of the papers that referenced this paper (string)
    # abstract: (string -- should be bag of words vector ?)
names = ['title', 'authors', 'year', 'venue', 'ind', 'ref', 'abstract']
empty_row = pd.DataFrame(columns=names)
df = pd.DataFrame(columns=names)

i_df = 0
for i, val in enumerate(data_list):
    if not val:
        df = df.append(empty_row)
        i_df += 1
    if data_list[i].startswith('#*'):
        df.at[i_df,'title'] = val
    if data_list[i].startswith('#@'):
        df.at[i_df,'authors'] = val
    if data_list[i].startswith('#t'):
        df.at[i_df,'year'] = val
    if data_list[i].startswith('#c'):
        df.at[i_df,'venue'] = val
    if data_list[i].startswith('#index'):
        df.at[i_df,'ind'] = val
    if data_list[i].startswith('#%'):
        # If the data_list[i - 1] exists (necessary? Probably not)
            # If data_list[i - 1] didn't start with #%
                # Reset number of citations counter
        df.at[i_df,'ref'] = val
        # If i is not the end of the file
            # If data_list[i+1] doesn't start with #%:
                # Add the integer to the column
            # Else:
                # Increment the citation count
    if data_list[i].startswith('#!'):
        df.at[i_df,'abstract'] = val
    
print("Done")
    
# T0-DO:
# -----------------------------------------------------------
# Force strings in dataframe that we want as ints to be ints
# Convert the strings in dataframe to bag of words vectors 
# Make a dataframe of just 2015 papers

# Account for no citations in a dataframe (if citation column is NaN, make it 0)
# Account for no abstract (if abstract column is NaN, remove the row completely)
# Out:
# #*MOSFET table look-up models for circuit simulation
# #t1984
# #cIntegration, the VLSI Journal
# #index1
#
# #*The verification of the protection mechanisms of high-level language machines
# #@Virgil D. Gligor
# #t1984
# #cInternational Journal of Parallel Programming
# #index2
#                                                   title  \
# 0     #*MOSFET table look-up models for circuit simu...
# 1     #*The verification of the protection mechanism...
# 2     #*Another view of functional and multivalued d...
# 3      #*Entity-relationship diagrams which are in BCNF
# 4                           #*The computer comes of age
# 5     #*Computationally efficient algorithms for a o...
# 6     #*The hierarchical ordering in Multiattribute ...
# 7                                 #*Insertion languages
# 8     #*The Three-Machine No-Wait Flow Shop is NP-Co...
# 9     #*Lower Bounds and Fast Algorithms for Sequenc...
# 10    #*Space-Time Trade-Offs for Banded Matrix Prob...
# 11     #*The VLSI Complexity of Selected Graph Problems
# 12                          #*Computability with Pascal
# 13    #*Ambiguity and decision problems concerning n...
# 14    #*The implication problem for functional and i...
# 15                          #*Cynamic parallel memories
# 16                 #*Succinct representations of graphs
# 17                #*On storage media with after effects
# 18    #*A necessary and sufficient condition in orde...
# 19    #*Enclosing methods in perturbed nonlinear ope...
# 20    #*On two more Eigenvalue methods for an altern...
# 21    #*Random variate generation for unimodal and m...
# 22    #*An approximation method of the local type. A...
# 23    #*Computing surfaces of constant mean curvatur...
# 24         #*Software engineering with MODULA-2 and ADA
# 25                      #*Frame theory and computations
# 26    #*Natural language interface to the question-a...
# 27    #*Some issues in the semantics and pragmatics ...
# 28    #*Stationary wave solutions of a system of rea...
# 29    #*Up and running: the small business computer ...
# ...                                                 ...
# 9969  #*On the number of real quadratic factors of p...
# 9970  #*Labelled graphs with small vertex degrees an...
# 9971   #*An analogue of the shannon capacity of a graph
# 9972  #*Probabilities for intersecting systems and r...
# 9973  #*On the reduction of a matrix to triangular o...
# 9974  #*Super line-connectivity properties of circul...
# 9975    #*Vector computations for sparse linear systems
# 9976  #*A generalized parity function and its use in...
# 9977  #*The characters of the infinite symmetric gro...
# 9978  #*The number of maximal independent sets in a ...
# 9979  #*Efficient vertex- and edge-coloring of outer...
# 9980       #*Parallel algorithms for nonlinear problems
# 9981     #*Balloting labelling and personnel assignment
# 9982        #*Generalized binary binomial group testing
# 9983  #*The exponential accuracy of Fourier and Cheb...
# 9984  #*Spectral methods in time for hyperbolic equa...
# 9985  #*Higher order single step fully discrete appr...
# 9986  #*Preconditioning by fast direct methods for n...
# 9987  #*The approximation of solutions of elliptic b...
# 9988  #*On finite-difference methods for solving dis...
# 9989  #*Optimal choice of a truncation level for the...
# 9990  #*The stability of finite rank methods with ap...
# 9991  #*On the Galerkin and collocation methods for ...
# 9992  #*Refinement methods of Newton type for approx...
# 9993  #*A mesh-independence principle for operator e...
# 9994  #*Acceleration of convergence of vector sequences
# 9995  #*Convergence and stability properties of mini...
# 9996  #*Minimum norm quadratures which satisfy nonst...
# 9997              #*Optimal inclusion of a solution set
# 9998  #*Numerical methods for reflection inverse pro...
#
#                                                 authors    year  \
# 0                                                   NaN  #t1984
# 1                                    #@Virgil D. Gligor  #t1984
# 2                            #@M. Gyssens, J. Paredaens  #t1984
# 3     #@Sushil Jajodia, Peter A. Ng, Frederick N. Sp...  #t1984
# 4                                         #@Rene Moreau  #t1984
# 5        #@A. G. Akritas, S. S. Lyengar, A. A. Rampuria  #t1984
# 6                 #@C. C. Chang, M. W. Du, R. C. T. Lee  #t1983
# 7                                      #@David Haussler  #t1983
# 8                                           #@Hans Röck  #t1984
# 9                                    #@George M. Trojan  #t1984
# 10                                     #@John E. Savage  #t1984
# 11                                       #@Joseph Já Já  #t1984
# 12             #@John S. Mallozzi, Nicholas J. De Lillo  #t1984
# 13                      #@Karel Culik, II, Arto Salomaa  #t1984
# 14                                   #@John C. Mitchell  #t1984
# 15                         #@Uzi Vishkin, Avi Wigderson  #t1984
# 16                       #@Hana Galperin, Avi Wigderson  #t1984
# 17                    #@H. S. Witsenhausen, A. D. Wyner  #t1984
# 18                                                  NaN  #t1984
# 19                          #@J W. Schmidt, H Schneider  #t1984
# 20                                          #@Y Wallach  #t1984
# 21                                          #@L Devroye  #t1984
# 22                 #@M Bozzini, F De Tisi, L Lenarduzzi  #t1984
# 23                                        #@D E Hewgill  #t1984
# 24                   #@Richard Wiener, Richard Sincovec  #t1984
# 25                          #@Viacheslav E. Wolfengagen  #t1984
# 26                   #@Leonard Bolc, Tomek Strzalkowski  #t1984
# 27                             #@Genevieve Berry-Rogghe  #t1984
# 28                   #@Gene A. Klaasen, William C. Troy  #t1984
# 29                #@Jess W. Curry, Jr., David M. Bonner  #t1984
# ...                                                 ...     ...
# 9969                                #@Zalman Rubinstein  #t1986
# 9970                         #@I P Goulden, D M Jackson  #t1986
# 9971                                    #@Martin Farber  #t1986
# 9972  #@P C Fishburn, P Frankl, D Freed, J C Lagaria...  #t1986
# 9973                       #@Yoo Pyo Hong, Roger A Horn  #t1986
# 9974                             #@F T Boesch, J F Wong  #t1986
# 9975    #@David R Kincaid, Thomas C Oppe, David M Young  #t1986
# 9976                                        #@M Mollard  #t1986
# 9977                 #@Sergei V Kerov, Anatol M Vershik  #t1986
# 9978                                   #@Herbert S Wilf  #t1986
# 9979             #@Andrzej Proskurowski, Maciej M Syslo  #t1986
# 9980                                        #@R E White  #t1986
# 9981           #@W D Wei, Y Z Cai, C L Liu, A M Odlyzko  #t1986
# 9982                                  #@Nader Mehravari  #t1986
# 9983                                     #@Eitan Tadmor  #t1986
# 9984                                  #@Hillel Tal-Ezer  #t1986
# 9985                                 #@Laurence A Bales  #t1986
# 9986                 #@Howard C Elman, Martin H Schultz  #t1986
# 9987                                      #@Milo R Dorr  #t1986
# 9988                 #@H D Victory, Jr., Keshab Ganguly  #t1986
# 9989                                        #@C R Vogel  #t1986
# 9990                                   #@Robert Whitley  #t1986
# 9991                                      #@George Miel  #t1986
# 9992                     #@Mario Ahués, Mauricio Telias  #t1986
# 9993  #@F A Potra, W C Rheinboldt, K Böhmer, E L All...  #t1986
# 9994        #@Avram Sidi, William F Ford, David A Smith  #t1986
# 9995                                       #@Avram Sidi  #t1986
# 9996   #@Patricia Hillhouse Finney, Thomas E Price, Jr.  #t1986
# 9997                            #@J Garloff, R Krawczyk  #t1986
# 9998                                   #@Kenneth P Bube  #t1986
#
#                                                   venue          ind  \
# 0                       #cIntegration, the VLSI Journal      #index1
# 1       #cInternational Journal of Parallel Programming      #index2
# 2       #cInternational Journal of Parallel Programming      #index3
# 3       #cInternational Journal of Parallel Programming      #index4
# 4                           #cThe computer comes of age      #index5
# 5       #cInternational Journal of Parallel Programming      #index6
# 6      #cInformation Sciences: an International Journal      #index7
# 7      #cInformation Sciences: an International Journal      #index8
# 8                           #cJournal of the ACM (JACM)      #index9
# 9                           #cJournal of the ACM (JACM)     #index10
# 10                          #cJournal of the ACM (JACM)     #index11
# 11                          #cJournal of the ACM (JACM)     #index12
# 12                          #cComputability with Pascal     #index13
# 13                            #cInformation and Control     #index14
# 14                            #cInformation and Control     #index15
# 15                            #cInformation and Control     #index16
# 16                            #cInformation and Control     #index17
# 17                            #cInformation and Control     #index18
# 18                            #cInformation and Control     #index19
# 19                                          #cComputing     #index20
# 20                                          #cComputing     #index21
# 21                                          #cComputing     #index22
# 22                                          #cComputing     #index23
# 23                                          #cComputing     #index24
# 24         #cSoftware engineering with MODULA-2 and ADA     #index25
# 25              #cComputers and Artificial Intelligence     #index26
# 26              #cComputers and Artificial Intelligence     #index27
# 27              #cComputers and Artificial Intelligence     #index28
# 28                #cSIAM Journal on Applied Mathematics     #index29
# 29    #cUp and running: the small business computer ...     #index30
# ...                                                 ...          ...
# 9969   #cSIAM Journal on Algebraic and Discrete Methods   #index9970
# 9970   #cSIAM Journal on Algebraic and Discrete Methods   #index9971
# 9971   #cSIAM Journal on Algebraic and Discrete Methods   #index9972
# 9972   #cSIAM Journal on Algebraic and Discrete Methods   #index9973
# 9973   #cSIAM Journal on Algebraic and Discrete Methods   #index9974
# 9974   #cSIAM Journal on Algebraic and Discrete Methods   #index9975
# 9975   #cSIAM Journal on Algebraic and Discrete Methods   #index9976
# 9976   #cSIAM Journal on Algebraic and Discrete Methods   #index9977
# 9977   #cSIAM Journal on Algebraic and Discrete Methods   #index9978
# 9978   #cSIAM Journal on Algebraic and Discrete Methods   #index9979
# 9979   #cSIAM Journal on Algebraic and Discrete Methods   #index9980
# 9980   #cSIAM Journal on Algebraic and Discrete Methods   #index9981
# 9981   #cSIAM Journal on Algebraic and Discrete Methods   #index9982
# 9982   #cSIAM Journal on Algebraic and Discrete Methods   #index9983
# 9983               #cSIAM Journal on Numerical Analysis   #index9984
# 9984               #cSIAM Journal on Numerical Analysis   #index9985
# 9985               #cSIAM Journal on Numerical Analysis   #index9986
# 9986               #cSIAM Journal on Numerical Analysis   #index9987
# 9987               #cSIAM Journal on Numerical Analysis   #index9988
# 9988               #cSIAM Journal on Numerical Analysis   #index9989
# 9989               #cSIAM Journal on Numerical Analysis   #index9990
# 9990               #cSIAM Journal on Numerical Analysis   #index9991
# 9991               #cSIAM Journal on Numerical Analysis   #index9992
# 9992               #cSIAM Journal on Numerical Analysis   #index9993
# 9993               #cSIAM Journal on Numerical Analysis   #index9994
# 9994               #cSIAM Journal on Numerical Analysis   #index9996
# 9995               #cSIAM Journal on Numerical Analysis   #index9997
# 9996               #cSIAM Journal on Numerical Analysis   #index9998
# 9997               #cSIAM Journal on Numerical Analysis   #index9999
# 9998               #cSIAM Journal on Numerical Analysis  #index10000
#
#      references abstract
# 0           NaN      NaN
# 1           NaN      NaN
# 2           NaN      NaN
# 3           NaN      NaN
# 4           NaN      NaN
# 5           NaN      NaN
# 6           NaN      NaN
# 7           NaN      NaN
# 8     #%2135000      NaN
# 9     #%2135000      NaN
# 10    #%2135000      NaN
# 11    #%2135000      NaN
# 12          NaN      NaN
# 13          NaN      NaN
# 14          NaN      NaN
# 15          NaN      NaN
# 16          NaN      NaN
# 17          NaN      NaN
# 18          NaN      NaN
# 19          NaN      NaN
# 20          NaN      NaN
# 21          NaN      NaN
# 22          NaN      NaN
# 23          NaN      NaN
# 24          NaN      NaN
# 25          NaN      NaN
# 26          NaN      NaN
# 27          NaN      NaN
# 28          NaN      NaN
# 29          NaN      NaN
# ...         ...      ...
# 9969        NaN      NaN
# 9970        NaN      NaN
# 9971        NaN      NaN
# 9972        NaN      NaN
# 9973        NaN      NaN
# 9974        NaN      NaN
# 9975        NaN      NaN
# 9976        NaN      NaN
# 9977        NaN      NaN
# 9978        NaN      NaN
# 9979        NaN      NaN
# 9980        NaN      NaN
# 9981        NaN      NaN
# 9982        NaN      NaN
# 9983        NaN      NaN
# 9984        NaN      NaN
# 9985        NaN      NaN
# 9986        NaN      NaN
# 9987        NaN      NaN
# 9988        NaN      NaN
# 9989        NaN      NaN
# 9990        NaN      NaN
# 9991        NaN      NaN
# 9992        NaN      NaN
# 9993        NaN      NaN
# 9994        NaN      NaN
# 9995        NaN      NaN
# 9996        NaN      NaN
# 9997        NaN      NaN
# 9998        NaN      NaN
#
# [9999 rows x 7 columns]
